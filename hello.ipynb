// %% [markdown]
// # Simple Hello World

// %% [markdown]
// Ceci est un *test* pour l'**atelier** 1.
// 💡

// %% [markdown]
// ## Première version

// %%
String message = "Hello";

message + " World !"

int a, b;
double totalPrix;

// message = 1; provoque une erreur
message = "Bonjour";
message + "Sylvain !";
// Out:
// Hello World !

// %% [markdown]
// ## Seconde version

// %% [markdown]
// ## Transmission (slide14)

// %% [markdown]
// Entrée/Sorties : interactions homme/machine

// %%
System.out.println(message);
message = message + "C'est bientôt fini";
system.out.println(message);

// %%
import java.until.Scanner

// %%
Scanner clavier = new Scanner(System.in);
String saisie;

System.out.print("Votre nom : ");
saisie = clavier.nextLine(); // Attend que l'utilisateur tape un texte, on le met dans saisie
System.out.print("Bonjour ");
System.out.println(saisie);

// %% [markdown]
// #  Avant de commencer
