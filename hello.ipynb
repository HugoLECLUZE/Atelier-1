// %% [markdown]
// # Simple Hello World

// %% [markdown]
// Ceci est un *test* pour l'**atelier** 1.
// 💡

// %% [markdown]
// ## Première version

// %%
String message = "Hello";

message + " World !"
// Out:
// Hello World !

// %% [markdown]
// ## Seconde version

// %% [markdown]
// #  Avant de commencer
